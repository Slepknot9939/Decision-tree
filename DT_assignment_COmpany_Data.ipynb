# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

df=pd.read_csv('Company_Data.csv')
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df['Sales']=pd.Numerical(df.Sales)
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e01163053112> in <module>
# ----> 1 df['Sales']=pd.Numerical(df.Sales)
#       2 df.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'Numerical'

# %%
label_encodder=preprocessing.LabelEncoder()
df['ShelveLoc']=label_encodder.fit_transform(df['ShelveLoc'])

# %%
label_encodder=preprocessing.LabelEncoder()
df['Urban']=label_encodder.fit_transform(df['Urban'])

# %%
label_encodder=preprocessing.LabelEncoder()
df['US']=label_encodder.fit_transform(df['US'])

# %%
#df=df.rename({'Good':0,'Bad':1,'Medium':2})

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          0   38
#
#    Education  Urban  US
# 0         17      1   1
# 1         10      1   1
# 2         12      1   1
# 3         14      1   1
# 4         13      1   0

# %%
df[df.duplicated()].shape
# Out:
# (0, 11)

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price   ShelveLoc         Age   Education       Urban          US
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   115.795000    1.307500   53.322500   13.900000    0.705000    0.645000
# std     23.676664    0.833475   16.200297    2.620528    0.456614    0.479113
# ...

# %%
#COnvert Sales numerical data to categorical

# %%
df['Sales']=pd.Categorical(df.Sales)
df.dtypes
# Out:
# Sales          category
# CompPrice         int64
# Income            int64
# Advertising       int64
# Population        int64
# Price             int64
# ShelveLoc         int32
# Age               int64
# Education         int64
# Urban             int32
# US                int32
# dtype: object

# %%
#df['ShelveLoc']=pd.Categorical(df.ShelveLoc)
#df.dtypes

# %%
X=df.iloc[:,1:]
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# ...

# %%
Y=df.iloc[:,:1]
Y
# Out:
#      Sales
# 0     9.50
# 1    11.22
# 2    10.06
# 3     7.40
# 4     4.15
# ..     ...
# 395  12.57
# 396   6.14
# 397   7.41
# 398   5.94
# 399   9.71
#
# [400 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=40)

# %%
x_train
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 389        128      42            8         328    107          2   35
# 21         134      29           12         239    109          1   62
# 142        124      84            0         300    104          2   77
# 163        130      64            0          40    106          0   39
# 382        121      28           19         315    121          2   66
# ..         ...     ...          ...         ...    ...        ...  ...
# 306        131      32            1          85    133          2   48
# 165        147      58            7         100    191          0   27
# 7          136      81           15         425    120          1   67
# 219        116      79           19         359    116          1   58
# 326        133      30            0         152    122          2   53
#
#      Education  Urban  US
# 389         12      1   1
# 21          18      0   1
# 142         15      1   0
# ...

# %%
y_train
# Out:
#      Sales
# 389   8.44
# 21   12.13
# 142   7.44
# 163   5.68
# 382   4.95
# ..     ...
# 306   4.78
# 165   0.37
# 7    11.85
# 219  10.62
# 326   4.69
#
# [280 rows x 1 columns]

# %%
model=DecisionTreeClassifier(criterion='entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-8b885fda0c16> in <module>
#       1 model=DecisionTreeClassifier(criterion='entropy',max_depth=3)
# ----> 2 model.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     179
#     180         if is_classification:
# --> 181             check_classification_targets(y)
#     182             y = np.copy(y)
#     183
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...
